# %%
# !pip install folium

# %%
from wordcloud import WordCloud
import folium
mymap=folium.Map(location=[13.248080466700975, 77.71278855156443],
                 width=950,
                 height=550,
                 zoom_start=13,
                 tiles='openstreetmap')

# %%
marker1=folium.Marker([13.248080466700975, 77.71278855156443], popup='/content/fort.jpg')
marker2=folium.Marker([13.250015676482098, 77.70942402775793], popup='My Fort')
marker3=folium.Marker([13.24640662100496, 77.7117063982732], popup='My Home')
marker4=folium.Marker([13.246997283698926, 77.71189455781459], popup='My Shop')
marker5=folium.Marker([13.24891134806284, 77.71226863312262], popup='My School')
marker1.add_to(mymap)
marker2.add_to(mymap)
marker3.add_to(mymap)
marker4.add_to(mymap)
marker5.add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
bang_Coords=(13.250015676482098, 77.70942402775793)
map_bang=folium.Map(location=bang_Coords, zoom_start=12)
places={
    "Devanahalli Fort":(13.250015676482098, 77.70942402775793),
    "My School":(13.24894725297109, 77.71231336302115),
    "International Air Port":(13.202210223105164, 77.70616843144374),
    "Tippu Birth Places":(13.246444779380026, 77.70710570246015),
    "Akash Hospital":(13.23396234516566, 77.70799723715605)
}

# %%
images={
    "Devanahalli Fort":"data:image/jpeg;base64,..."
    "My School":"data:image/jpeg;base64,..."
    "International Airport":"data:image/jpeg;base64,..."
    "Tippu Birth Place":"data:image/jpeg;base64,..."
    "Akash Hospital":"data:image/jpeg;base64,..."
    }
for place, coords in places.items():
  popup_content=f'<b>{place}</b>'
  folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bang)
  map_bang
# Out:
#   File "<ipython-input-27-7298ff3a1bce>", line 3
#     "My School":"data:image/jpeg;base64,......
#                ^
# SyntaxError: invalid syntax
